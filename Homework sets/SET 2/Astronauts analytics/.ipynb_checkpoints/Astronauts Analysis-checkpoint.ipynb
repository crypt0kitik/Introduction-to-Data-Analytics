# %%
# https://think.cs.vt.edu/corgis/csv/astronauts/

# question: Who had more chances to become an astronaut?

# %%
# import modules
# numpy and pandas for downloading and analyzing
# seaborn and matplotlib for plots and chars
# dtale for open df in the browser for analyzing
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import dtale

# %%
# download and read the data
df = pd.read_csv('astronauts.csv')
df
# Out:
#       Profile.Astronaut Numbers.Overall  Profile.Astronaut Numbers.Nationwide  \
# 0                                     1                                     1
# 1                                     2                                     2
# 2                                     3                                     1
# 3                                     3                                     1
# 4                                     4                                     2
# ...                                 ...                                   ...
# 1265                                561                                   345
# 1266                                562                                   346
# 1267                                563                                   347
# 1268                                564                                   348
# 1269                                565                                     1
#
#                  Profile.Name Profile.Gender  Profile.Birth Year  \
# 0               Gagarin, Yuri           male                1934
# 1              Titov, Gherman           male                1935
# 2         Glenn, John H., Jr.           male                1921
# 3         Glenn, John H., Jr.           male                1921
# 4         Carpenter, M. Scott           male                1925
# ...                       ...            ...                 ...
# 1265  McClain, Anne Charlotte         female                1979
# 1266          Koch, Christina         female                1979
# 1267           Morgan, Andrew           male                1976
# 1268            Meir, Jessica         female                1977
# 1269      Al Mansoori, Hazzaa           male                1983
#
#      Profile.Nationality  Profile.Military Profile.Selection.Group  \
# 0         U.S.S.R/Russia              True                  TsPK-1
# 1         U.S.S.R/Russia              True                  TsPK-1
# 2                   U.S.              True  NASA Astronaut Group 1
# 3                   U.S.              True  NASA Astronaut Group 2
# 4                   U.S.              True                 NASA- 1
# ...                  ...               ...                     ...
# 1265                U.S.              True                 NASA-21
# 1266                U.S.              True                 NASA-21
# 1267                U.S.              True                 NASA-21
# 1268                U.S.              True                 NASA-21
# 1269                 UAE              True       MBRSC Selection 1
#
#       Profile.Selection.Year  Profile.Lifetime Statistics.Mission count  \
# 0                       1960                                          1
# 1                       1960                                          1
# 2                       1959                                          2
# 3                       1959                                          2
# 4                       1959                                          1
# ...                      ...                                        ...
# 1265                    2013                                          1
# 1266                    2013                                          1
# 1267                    2013                                          1
# 1268                    2013                                          1
# 1269                    2018                                          1
#
#                  Mission.Role  Mission.Year     Mission.Name  \
# 0                       pilot          1961         Vostok 1
# 1                       pilot          1961         Vostok 2
# 2                       pilot          1962             MA-6
# 3                         PSP          1998           STS-95
# 4                       Pilot          1962  Mercury-Atlas 7
# ...                       ...           ...              ...
# 1265          flight engineer          2018               57
# 1266          flight engineer          2019               59
# 1267          flight engineer          2019               60
# 1268          flight engineer          2019               60
# 1269  spaceflight participant          2019            EP-19
#
#      Mission.Vechicles.Ascent Mission.Vechicles.Orbit  \
# 0                    Vostok 1                Vostok 2
# 1                    Vostok 2                Vostok 2
# 2                        MA-6                    MA-6
# 3                      STS-95                  STS-95
# 4             Mercury-Atlas 7         Mercury-Atlas 7
# ...                       ...                     ...
# 1265              Soyuz MS-11                     ISS
# 1266              Soyuz MS-12                     ISS
# 1267              Soyuz MS-13                     ISS
# 1268              Soyuz MS-15                     ISS
# 1269              Soyuz MS-15                     ISS
#
#      Mission.Vechicles.Decent  Mission.Durations.Mission duration  \
# 0                    Vostok 3                                1.77
# 1                    Vostok 2                               25.00
# 2                        MA-6                                5.00
# 3                      STS-95                              213.00
# 4             Mercury-Atlas 7                                5.00
# ...                       ...                                 ...
# 1265              Soyuz MS-11                             4887.00
# 1266        not completed yet                             7372.30
# 1267        not completed yet                             4303.08
# 1268        not completed yet                             2697.60
# 1269              Soyuz MS-12                              189.00
#
#       Profile.Lifetime Statistics.Mission duration  \
# 0                                             1.77
# 1                                            25.30
# 2                                           218.00
# 3                                           218.00
# 4                                             5.00
# ...                                            ...
# 1265                                       4887.00
# 1266                                       7372.30
# 1267                                       4303.08
# 1268                                       2697.60
# 1269                                        189.00
#
#       Mission.Durations.EVA duration  Profile.Lifetime Statistics.EVA duration
# 0                               0.00                                      0.00
# 1                               0.00                                      0.00
# 2                               0.00                                      0.00
# 3                               0.00                                      0.00
# 4                               0.00                                      0.00
# ...                              ...                                       ...
# 1265                           13.13                                     13.13
# 1266                           27.80                                     27.80
# 1267                           39.52                                     39.52
# 1268                            7.28                                      7.28
# 1269                            0.00                                      0.00
#
# [1270 rows x 20 columns]

# %%
# see what columns we have
df.columns
# Out:
# Index(['Profile.Astronaut Numbers.Overall',
#        'Profile.Astronaut Numbers.Nationwide', 'Profile.Name',
#        'Profile.Gender', 'Profile.Birth Year', 'Profile.Nationality',
#        'Profile.Military', 'Profile.Selection.Group', 'Profile.Selection.Year',
#        'Profile.Lifetime Statistics.Mission count', 'Mission.Role',
#        'Mission.Year', 'Mission.Name', 'Mission.Vechicles.Ascent',
#        'Mission.Vechicles.Orbit', 'Mission.Vechicles.Decent',
#        'Mission.Durations.Mission duration',
#        'Profile.Lifetime Statistics.Mission duration',
#        'Mission.Durations.EVA duration',
#        'Profile.Lifetime Statistics.EVA duration'],
#       dtype='object')

# %%
# we can delete columns which are unusefull
# this column does not affect on analysis
df = df.drop('Profile.Astronaut Numbers.Nationwide', axis = 1)

# %%
# we need to rename columns
df = df.rename(columns={"Profile.Astronaut Numbers.Overall": "Astronaut_Number", "Profile.Name": "Name", "Profile.Gender": "Gender", "Profile.Birth Year": "Birth_Year"})
df = df.rename(columns={"Profile.Nationality": "Nationality", "Profile.Military": "Military", "Profile.Selection.Group": "Selection_Group", "Profile.Selection.Year": "Selection_Year"})
df = df.rename(columns={"Profile.Lifetime Statistics.Mission count": "Mission_count", "Mission.Name": "Mission_Name", "Mission.Role": "Mission_Role", "Mission.Year": "Mission_Year", "Mission.Vechicles.Ascent": "Mission_Vechicles", "Mission.Vechicles.Orbit": "Mission_Vechicles_Orbit"})
df = df.rename(columns={"Mission.Vechicles.Decent": "Mission_Vechicles_Decent", "Mission.Durations.Mission duration": "Mission_Duration", "Profile.Lifetime Statistics.Mission duration": "Lifetime_Mission_Duration", "Mission.Durations.EVA duration": "Mission_EVA_Duration", "Profile.Lifetime Statistics.EVA duration": "Lifetime_EVA_Duration"})
df
# Out:
#       Astronaut_Number                     Name  Gender  Birth_Year  \
# 0                    1            Gagarin, Yuri    male        1934
# 1                    2           Titov, Gherman    male        1935
# 2                    3      Glenn, John H., Jr.    male        1921
# 3                    3      Glenn, John H., Jr.    male        1921
# 4                    4      Carpenter, M. Scott    male        1925
# ...                ...                      ...     ...         ...
# 1265               561  McClain, Anne Charlotte  female        1979
# 1266               562          Koch, Christina  female        1979
# 1267               563           Morgan, Andrew    male        1976
# 1268               564            Meir, Jessica  female        1977
# 1269               565      Al Mansoori, Hazzaa    male        1983
#
#          Nationality  Military         Selection_Group  Selection_Year  \
# 0     U.S.S.R/Russia      True                  TsPK-1            1960
# 1     U.S.S.R/Russia      True                  TsPK-1            1960
# 2               U.S.      True  NASA Astronaut Group 1            1959
# 3               U.S.      True  NASA Astronaut Group 2            1959
# 4               U.S.      True                 NASA- 1            1959
# ...              ...       ...                     ...             ...
# 1265            U.S.      True                 NASA-21            2013
# 1266            U.S.      True                 NASA-21            2013
# 1267            U.S.      True                 NASA-21            2013
# 1268            U.S.      True                 NASA-21            2013
# 1269             UAE      True       MBRSC Selection 1            2018
#
#       Mission_count             Mission_Role  Mission_Year     Mission_Name  \
# 0                 1                    pilot          1961         Vostok 1
# 1                 1                    pilot          1961         Vostok 2
# 2                 2                    pilot          1962             MA-6
# 3                 2                      PSP          1998           STS-95
# 4                 1                    Pilot          1962  Mercury-Atlas 7
# ...             ...                      ...           ...              ...
# 1265              1          flight engineer          2018               57
# 1266              1          flight engineer          2019               59
# 1267              1          flight engineer          2019               60
# 1268              1          flight engineer          2019               60
# 1269              1  spaceflight participant          2019            EP-19
#
#      Mission_Vechicles Mission_Vechicles_Orbit Mission_Vechicles_Decent  \
# 0             Vostok 1                Vostok 2                 Vostok 3
# 1             Vostok 2                Vostok 2                 Vostok 2
# 2                 MA-6                    MA-6                     MA-6
# 3               STS-95                  STS-95                   STS-95
# 4      Mercury-Atlas 7         Mercury-Atlas 7          Mercury-Atlas 7
# ...                ...                     ...                      ...
# 1265       Soyuz MS-11                     ISS              Soyuz MS-11
# 1266       Soyuz MS-12                     ISS        not completed yet
# 1267       Soyuz MS-13                     ISS        not completed yet
# 1268       Soyuz MS-15                     ISS        not completed yet
# 1269       Soyuz MS-15                     ISS              Soyuz MS-12
#
#       Mission_Duration  Lifetime_Mission_Duration  Mission_EVA_Duration  \
# 0                 1.77                       1.77                  0.00
# 1                25.00                      25.30                  0.00
# 2                 5.00                     218.00                  0.00
# 3               213.00                     218.00                  0.00
# 4                 5.00                       5.00                  0.00
# ...                ...                        ...                   ...
# 1265           4887.00                    4887.00                 13.13
# 1266           7372.30                    7372.30                 27.80
# 1267           4303.08                    4303.08                 39.52
# 1268           2697.60                    2697.60                  7.28
# 1269            189.00                     189.00                  0.00
#
#       Lifetime_EVA_Duration
# 0                      0.00
# 1                      0.00
# 2                      0.00
# 3                      0.00
# 4                      0.00
# ...                     ...
# 1265                  13.13
# 1266                  27.80
# 1267                  39.52
# 1268                   7.28
# 1269                   0.00
#
# [1270 rows x 19 columns]

# %%
# let's see do we have more male or female austronats
# we can see that numbers are almost same
# it means that gender does not affect on becoming an austronaut
sns.barplot(x='Astronaut_Number',y='Gender',data=df)
plt.show()

# %%
# let's the most common nationalities
# we need to take into account
# that data is limited by time (1921-1983 years)
# we could see that there are more astroanuts from U.S. and U.S.S.R
purposes = df['Nationality'].value_counts()
purposes.head(5)
# Out:
# U.S.              850
# U.S.S.R/Russia    273
# Japan              20
# France             18
# Canada             18
# Name: Nationality, dtype: int64

# %%
# let's the most popular year of an astronaut
# we could see that there are more astroanuts
# who were born between 1949-1956 year
purposes = df['Birth_Year'].value_counts()
purposes.head(10)
# Out:
# 1956    78
# 1958    59
# 1957    55
# 1951    55
# 1952    54
# 1949    51
# 1961    41
# 1964    41
# 1959    40
# 1955    40
# Name: Birth_Year, dtype: int64

# %%
# let's see were these people in Military or not

# %%
# let's see do we have any correlations between Mission_Role and becoming an astronaut
# Do some roles get easier?

# %%
# Do we have any correlation between Mission_count and Lifetime_Mission_Duration?
# If more count, more Duration?

# %%
# Do we have popular Mission_Name?
# Is it possible that one mission needeed bigger amount of astronauts?

# %%
# Who has the biggest Lifetime_Mission_Duration?
# Do they have our features that we needed to become an astronaut?

# %%
# To sum up,
# If a person was born in U.S. or U.S.S.R
# they had more chances to become an astronaut
