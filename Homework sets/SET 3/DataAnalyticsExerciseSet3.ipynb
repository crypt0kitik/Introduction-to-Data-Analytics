# %% [markdown]
# <h3><b>Introduction to Data Analytics - Exercise set 3 - seaborn-module and data exploration</b></h3>

# %% [markdown]
# Put all your exercises (Jupyter Notebooks or Python-files) in your course Git-project.
# Use either code comments or Jupyter Notebook markdown (text) to document which exercise you are doing and what a certain code section does!
# You can return all of these exercises in a single Jupyter Notebook, if you wish.

# %% [markdown]
# <h4><b>1.In this exercise, use the 'penguins' dataset from seaborn! </b></h4>
# <b>-> sns.load_dataset('penguins')
# </b>

# %%
# you can import numpy and pandas here
# and also load the needed dataset
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# <ul>
# <li>Create a pair plot of the data</li>
# <ul>
#     <li>What correlations can you immediately see?</li>
#     <li><b>Bonus extra task:</b> check out the correlation matrix for this dataset too ?</li>
# </ul>
# </ul>

# %%
# create a pair plot of the data
sns.pairplot(penguins)

# we immediately can see correlation between flipper_length_mm and body_mass_g

# %%
# Bonus extra task: check out the correlation matrix for this dataset too
correlations = penguins.corr(numeric_only=True)
correlations

# by this matrix we could also see that there is a correlation
# between flipper_length_mm and bill_length_mm 
# correlation is 0.66
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %% [markdown]
# <li>Use hue for the "island" column, what do you learn from the data this way?</li>

# %%
# Use hue for the "island" column, what do you learn from the data this way?
sns.pairplot(penguins, hue='island')
plt.show()

# we can see that there 3 islands
# the Biscoe island has correlations with bill_length_mm and body_mass_g
# Does it mean that penguins who live at Biscoe have longer bill and bigger mass?

# %% [markdown]
# <ul>
#     <li>Find the amount of penguins on each island by using pandas (<b>value_counts()</b>). Which island does not belong in the group?</li>
#     <ul>
#         <li><b>Small extra task:</b> visualize the counts with a bar plot</li>
#     </ul>
# </ul>

# %%
# to understand how many islands we have
# I did not understand a quesion "Which island does not belong in the group?"
islands = penguins['island'].value_counts()
islands.head(10)
# Out:
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: island, dtype: int64

# %%
# the amount of penguins on the Torgersen island
penguins[penguins['island'] == "Torgersen"].count()
# Out:
# species              52
# island               52
# bill_length_mm       51
# bill_depth_mm        51
# flipper_length_mm    51
# body_mass_g          51
# sex                  47
# dtype: int64

# %%
# the amount of penguins on the Biscoe island
penguins[penguins['island'] == "Biscoe"].count()
# Out:
# species              168
# island               168
# bill_length_mm       167
# bill_depth_mm        167
# flipper_length_mm    167
# body_mass_g          167
# sex                  163
# dtype: int64

# %%
# the amount of penguins on the Dream island
penguins[penguins['island'] == "Dream"].count()
# Out:
# species              124
# island               124
# bill_length_mm       124
# bill_depth_mm        124
# flipper_length_mm    124
# body_mass_g          124
# sex                  123
# dtype: int64

# %% [markdown]
# <ul>
#     <li>Create now another pair plot, and use hue for the "species" –column</li>
#     <ul>
#         <li>Is there a difference when compared to islands?</li>
#         <li><b>Bonus task:</b> How much does the "sex"-column affect the result ? (MALE / FEMALE)</li>
#     </ul>
# </ul>

# %%
# Small extra task: visualize the counts with a bar plot
# sns.barplot(x='island', y='species', data=penguins)

# %%
#  pair plot, and use hue for the "species" –column
sns.pairplot(penguins, hue='species')
plt.show()

# %% [markdown]
# <ul>
#     <li>Create a scatter plot for <b><i>bill_length_mm</i></b> and <b><i>flipper_length_mm</i></b>, use species as hue (try also island as hue)</li>
#     <ul>
#         <li>Which affects the result more, species or island?</li>
#     </ul>
# </ul>

# %%
# scatter plot for bill_length_mm and flipper_length_mm, use species as hue (try also island as hue)
sns.jointplot(x='bill_length_mm', y='flipper_length_mm', hue = "species", data=penguins)
plt.show()

# %%
# scatter plot for bill_length_mm and flipper_length_mm, use species as hue (try also island as hue)
sns.jointplot(x='bill_length_mm', y='flipper_length_mm', hue = "island", data=penguins)
plt.show()

# we could see that island has more correlation than species
# probably, habitation area affects more that the original species type

# %% [markdown]
# <ul>
#     <li>Use box plot, violin plot or swarm plot:</li>
#     <ul>
#         <li>inspect the following information:</li>
#         <ul>
#             <li><b></i>flipper_length_mm</i></b></li>
#             <li><b></i>bill_length_mm</i></b></li>
#             <li><b></i>body_mass_g</i></b></li>
#         </ul>
#         <li>hue = island,  x= species</li>
#         <li>What interesting features can you find this way?</li>
#     </ul>
# </ul>

# %%
# box / violin / swarm plot
sns.boxplot(x='species', y='flipper_length_mm', data=penguins, hue="island")
plt.show()

# we can see that Gentoo species are located only on the Biscoe island. And they have the biggest length of flipper
# we also can say that species which live on the Adelie island have smaller length of a bill
# it means that living area affects on this measure

# %%
# box / violin / swarm plot
sns.boxplot(x='species', y='bill_length_mm', data=penguins, hue="island")
plt.show()

# here we can see that Gentoo and Chinstrap species have almost the the same lenght of a bill
# we also can say that species which live on the Adelie island have smaller length of a bill
# it means that living area affects on this measure

# %%
# box / violin / swarm plot
sns.boxplot(x='species', y='body_mass_g', data=penguins, hue="island")
plt.show()

# considering this and previous plots we can say that Gentoo has almost the biggest species
# or contrary, species on the Adeile island have smallest features
# it means that living area affects on this measure

# %% [markdown]
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_3/penguins.png" />

# %% [markdown]
# <h4><b>2. In this exercise, use the 'mpg' dataset from seaborn! </b></h4>
# <b>-> sns.load_dataset('mpg')</b>
# <p>
# mpg stands for "miles per gallon", which is a common way to represent fuel consumption in USA.
# </p>

# %% [markdown]
# <b>Clean up the data (instructions and tasks below)</b>

# %% [markdown]
# <ul>
# <li>Create a new column: <b>"liters_per_100km"</b> , which converts the mpg to liters per 100 km</li>
# <ul>
# <li>you can Google the conversion formula easily: "miles per gallon to liters per 100km", or:<br />
# <a href="https://www.calculateme.com/gas-mileage/us-mpg-to-liters-per-100-km">https://www.calculateme.com/gas-mileage/us-mpg-to-liters-per-100-km</a>
# </li>
# <li>remove the original mpg –column after this</li>
# </ul>
#
# </ul>

# %%
# download the dataset and read it
df = sns.load_dataset('mpg')
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# 1            70     usa          buick skylark 320
# 2            70     usa         plymouth satellite
# 3            70     usa              amc rebel sst
# 4            70     usa                ford torino
# ..          ...     ...                        ...
# 393          82     usa            ford mustang gl
# 394          82  europe                  vw pickup
# 395          82     usa              dodge rampage
# 396          82     usa                ford ranger
# 397          82     usa                 chevy s-10
#
# [398 rows x 9 columns]

# %%
# Clean up the data
# Create a new column: "liters_per_100km" , which converts the mpg to liters per 100 km

# I used this formula to convert (https://www.wikihow.com/Convert-MPG-to-Liters-per-100km)
# l / 100 km = 282.48 / mpg
df['liters_per_100km'] = 282.48 / df['mpg']

# I wanted to round but it did not work
# df['liters_per_100km'].round(3)

# remove the original mpg
df = df.drop('mpg', axis = 1)

# %% [markdown]
# <li>After this, create a correlation matrix. There are two
# columns that do not correlate as much as the others,
# remove these two from the dataset</li>

# %%
# Create a correlation matrix
# There are two columns that do not correlate as much as the others, remove them
correlations = df.corr()
correlations

# we can see that "acceleration" and "model_year" columns have more negative numbers
# it means, that that they have less correlations
# we will remove them
df = df.drop('acceleration', axis = 1)
df = df.drop('model_year', axis = 1)

# I cannot use (numeric_only=True) here because I have not numeric columns
# Out:
# /var/folders/20/hrkxfm3x44z9qt9zqv_zchj00000gn/T/ipykernel_31156/2656161189.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = df.corr()

# %%
# I deleted not numeric columns
# now I can run the command without errors
correlations = df.corr(numeric_only=True)
correlations
# Out:
#                   cylinders  displacement  horsepower    weight  \
# cylinders          1.000000      0.950721    0.842983  0.896017
# displacement       0.950721      1.000000    0.897257  0.932824
# horsepower         0.842983      0.897257    1.000000  0.864538
# weight             0.896017      0.932824    0.864538  1.000000
# liters_per_100km   0.839278      0.866631    0.854809  0.885219
#
#                   liters_per_100km
# cylinders                 0.839278
# displacement              0.866631
# horsepower                0.854809
# weight                    0.885219
# liters_per_100km          1.000000

# %% [markdown]
# <ul>
# <li>There are three different columns that are strongly
# connected to the car's efficiency (both power and
# consumption), select one of them and remove the others
# from the dataset
# </li>
# <ul>
# <li>Which column is the best selection to indicate the
# car’s efficiency, and why? (cylinders, horsepower or
# displacement/engine size)</li>
# </ul>
# </ul>

# %%
# There are three different columns that are strongly connected to both power and consumption
# select one of them and remove the others from the dataset
correlations = df.corr(numeric_only=True)
correlations

# we can see that displacement has the best selection to indicate the car’s efficiency
# because displacement's correlations are bigger than others
# Out:
#                   cylinders  displacement  horsepower    weight  \
# cylinders          1.000000      0.950721    0.842983  0.896017
# displacement       0.950721      1.000000    0.897257  0.932824
# horsepower         0.842983      0.897257    1.000000  0.864538
# weight             0.896017      0.932824    0.864538  1.000000
# liters_per_100km   0.839278      0.866631    0.854809  0.885219
#
#                   liters_per_100km
# cylinders                 0.839278
# displacement              0.866631
# horsepower                0.854809
# weight                    0.885219
# liters_per_100km          1.000000

# %% [markdown]
# <ul>
#     <li><b>Finally, use the pair plot and hue (origin)</b></li>
#     <ul>
#         <li>Which origin country tends have bigger fuel consumption in
# cars?</li>
# <li>Which is generally the origin with lowest consumption?
# (more specific plots might be a good idea here, for example:
# box plot, scatter plot etc., pandas functions are helpful too!)</li>
# <li>What other features the cars seem to have that result into
# bigger or lower consumption?</li>
#     </ul>
# </ul>

# %%
# pair plot and hue (origin)
sns.pairplot(df, hue="origin")
plt.show()

# Which origin country tends have bigger fuel consumption in cars?
# USA have bigger measurements fir liters per 100km

# Which is generally the origin with lowest consumption?
# Europe have lowest measurements fir liters per 100km

# What other features the cars seem to have that result into bigger or lower consumption?
# We can see that weight. horsepower and displecement impact on consumption
# if these metrics are bigger, consumption is bigger

# %% [markdown]
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_3/mpg.png" />

# %% [markdown]
# <h4><b>3. csv-data, pandas and seaborn</b></h4>

# %% [markdown]
# <p>
# This dataset has been downloaded from <b><i>kaggle.com</i></b>.<br />
# Download the "groceries.csv" from Moodle.
# <br /><br />
# Load the data by using pandas. (read_csv() etc.)
# <br /><br />
#
# <b>Note:</b> since this is an actual dataset from the internet, the data is in quite a rough format.
#
# </p>

# %% [markdown]
# <li>If you take a look at the data, you will notice three columns have NaN –
# values. You can either remove these columns all together, or you can fill
# the missing values with average values of that column. For example, for
# the Fish -column you could do something like this:<br /><br />
#
# <b>food['Fish'].fillna((food['Fish'].mean()), inplace=True)</b><br /><br />
# In this case, food is the name of the DataFrame we just got from the csv-file. Do this same operation to the two other columns with missing
# values.</li>

# %%
# handle incomplete rows here, justify your approach on how you handled them
df = pd.read_csv("groceries.csv")
df
# Out:
#       Month  Rice  Wheat  Barley  Corn  Peanuts   Sugar  Coconut-oil  \
# 0    Oct-90  0.28   0.11    0.09  0.10     2.12  0.0049         0.28
# 1    Nov-90  0.27   0.11    0.09  0.10     2.11  0.0049         0.34
# 2    Dec-90  0.26   0.11    0.09  0.10     2.00  0.0046         0.32
# 3    Jan-91  0.30   0.11    0.09  0.11     1.85  0.0042         0.34
# 4    Feb-91  0.33   0.11    0.09  0.11     1.79  0.0042         0.33
# ..      ...   ...    ...     ...   ...      ...     ...          ...
# 355  May-20  0.51   0.21    0.08  0.14     2.05  0.0053         0.83
# 356  Jun-20  0.52   0.20    0.08  0.15     2.05  0.0060         0.92
# 357  Jul-20  0.48   0.20    0.08  0.15     1.99  0.0060         0.89
# 358  Aug-20  0.50   0.20    0.08  0.15     1.30  0.0064         0.98
# 359  Sep-20  0.51   0.20    0.08  0.17     1.68  0.0062         1.03
#
#      Palm-oil  Sunflower-oil  Chicken    Beef    Pork  Fish   Tea  Coffee
# 0        0.29           0.58   0.0236  0.0571  2.5051  6.35  1.60    1.24
# 1        0.33           0.56   0.0236  0.0558  2.4414  6.46  1.58    1.22
# 2        0.35           0.55   0.0231  0.0562  2.3479  6.50  1.52    1.24
# 3        0.35           0.57   0.0231  0.0571  2.6495  6.34  1.55    1.16
# 4        0.34           0.60   0.0238  0.0602  2.3517  6.41  1.48    1.14
# ..        ...            ...      ...     ...     ...   ...   ...     ...
# 355      0.58            NaN   0.0335  0.1120     NaN   NaN  1.97    1.42
# 356      0.66            NaN   0.0346  0.1124     NaN   NaN  1.86    1.42
# 357      0.69            NaN   0.0335  0.1036     NaN   NaN  1.78    1.49
# 358      0.76            NaN   0.0331  0.1021     NaN   NaN  2.00    1.60
# 359      0.80            NaN   0.0324  0.1014     NaN   NaN  2.05    1.60
#
# [360 rows x 16 columns]

# %%
# fill the missing values with average values 
df['Sunflower-oil'].fillna((df['Sunflower-oil'].mean()), inplace=True)
df['Fish'].fillna((df['Fish'].mean()), inplace=True)
df['Pork'].fillna((df['Pork'].mean()), inplace=True)
df
# Out:
#       Month  Rice  Wheat  Barley  Corn  Peanuts   Sugar  Coconut-oil  \
# 0    Oct-90  0.28   0.11    0.09  0.10     2.12  0.0049         0.28
# 1    Nov-90  0.27   0.11    0.09  0.10     2.11  0.0049         0.34
# 2    Dec-90  0.26   0.11    0.09  0.10     2.00  0.0046         0.32
# 3    Jan-91  0.30   0.11    0.09  0.11     1.85  0.0042         0.34
# 4    Feb-91  0.33   0.11    0.09  0.11     1.79  0.0042         0.33
# ..      ...   ...    ...     ...   ...      ...     ...          ...
# 355  May-20  0.51   0.21    0.08  0.14     2.05  0.0053         0.83
# 356  Jun-20  0.52   0.20    0.08  0.15     2.05  0.0060         0.92
# 357  Jul-20  0.48   0.20    0.08  0.15     1.99  0.0060         0.89
# 358  Aug-20  0.50   0.20    0.08  0.15     1.30  0.0064         0.98
# 359  Sep-20  0.51   0.20    0.08  0.17     1.68  0.0062         1.03
#
#      Palm-oil  Sunflower-oil  Chicken    Beef      Pork      Fish   Tea  \
# 0        0.29       0.580000   0.0236  0.0571  2.505100  6.350000  1.60
# 1        0.33       0.560000   0.0236  0.0558  2.441400  6.460000  1.58
# 2        0.35       0.550000   0.0231  0.0562  2.347900  6.500000  1.52
# 3        0.35       0.570000   0.0231  0.0571  2.649500  6.340000  1.55
# 4        0.34       0.600000   0.0238  0.0602  2.351700  6.410000  1.48
# ..        ...            ...      ...     ...       ...       ...   ...
# 355      0.58       0.914201   0.0335  0.1120  1.500345  4.806947  1.97
# 356      0.66       0.914201   0.0346  0.1124  1.500345  4.806947  1.86
# 357      0.69       0.914201   0.0335  0.1036  1.500345  4.806947  1.78
# 358      0.76       0.914201   0.0331  0.1021  1.500345  4.806947  2.00
# 359      0.80       0.914201   0.0324  0.1014  1.500345  4.806947  2.05
#
#      Coffee
# 0      1.24
# 1      1.22
# 2      1.24
# 3      1.16
# 4      1.14
# ..      ...
# 355    1.42
# 356    1.42
# 357    1.49
# 358    1.60
# 359    1.60
#
# [360 rows x 16 columns]

# %% [markdown]
# <ul>
# <li>In this data, the date column is a bit difficult to use, since it's not
# completely in numerical format. Split the Month-column so, that you
# have two different columns: Month and Year</li>
# <ul>
# <li>For month, use a numeric format 1-12</li>
# <li>For year, use the full year 1990-2020</li>
# <li>Check out the examples in Moodle, this one is a bit tricky, but
# very neat to know how it's done!</li>
# </ul>
# </ul>

# %%
# split the Month-column
df["Year"] = df['Month'].str.slice(4, 6).astype(int)
df["Month"] = df['Month'].str.slice(0, 3)
df
# Out:
#     Month  Rice  Wheat  Barley  Corn  Peanuts   Sugar  Coconut-oil  Palm-oil  \
# 0     Oct  0.28   0.11    0.09  0.10     2.12  0.0049         0.28      0.29
# 1     Nov  0.27   0.11    0.09  0.10     2.11  0.0049         0.34      0.33
# 2     Dec  0.26   0.11    0.09  0.10     2.00  0.0046         0.32      0.35
# 3     Jan  0.30   0.11    0.09  0.11     1.85  0.0042         0.34      0.35
# 4     Feb  0.33   0.11    0.09  0.11     1.79  0.0042         0.33      0.34
# ..    ...   ...    ...     ...   ...      ...     ...          ...       ...
# 355   May  0.51   0.21    0.08  0.14     2.05  0.0053         0.83      0.58
# 356   Jun  0.52   0.20    0.08  0.15     2.05  0.0060         0.92      0.66
# 357   Jul  0.48   0.20    0.08  0.15     1.99  0.0060         0.89      0.69
# 358   Aug  0.50   0.20    0.08  0.15     1.30  0.0064         0.98      0.76
# 359   Sep  0.51   0.20    0.08  0.17     1.68  0.0062         1.03      0.80
#
#      Sunflower-oil  Chicken    Beef      Pork      Fish   Tea  Coffee  Year
# 0         0.580000   0.0236  0.0571  2.505100  6.350000  1.60    1.24    90
# 1         0.560000   0.0236  0.0558  2.441400  6.460000  1.58    1.22    90
# 2         0.550000   0.0231  0.0562  2.347900  6.500000  1.52    1.24    90
# 3         0.570000   0.0231  0.0571  2.649500  6.340000  1.55    1.16    91
# 4         0.600000   0.0238  0.0602  2.351700  6.410000  1.48    1.14    91
# ..             ...      ...     ...       ...       ...   ...     ...   ...
# 355       0.914201   0.0335  0.1120  1.500345  4.806947  1.97    1.42    20
# 356       0.914201   0.0346  0.1124  1.500345  4.806947  1.86    1.42    20
# 357       0.914201   0.0335  0.1036  1.500345  4.806947  1.78    1.49    20
# 358       0.914201   0.0331  0.1021  1.500345  4.806947  2.00    1.60    20
# 359       0.914201   0.0324  0.1014  1.500345  4.806947  2.05    1.60    20
#
# [360 rows x 17 columns]

# %%
# function to use a numeric format 1-12
def month_to_numeric(row):
    if row['Month'] == "Jan":
        return 1
    elif row['Month'] == "Feb":
        return 2
    elif row['Month'] == "Mar":
        return 3
    elif row['Month'] == "Apr":
        return 4
    elif row['Month'] == "May":
        return 5
    elif row['Month'] == "Jun":
        return 6
    elif row['Month'] == "Jul":
        return 7
    elif row['Month'] == "Aug":
        return 8
    elif row['Month'] == "Sep":
        return 9
    elif row['Month'] == "Oct":
        return 10
    elif row['Month'] == "Nov":
        return 11
    else: 
        return 12
    
df['Month'] = df.apply(month_to_numeric, axis=1)
df
# Out:
#      Month  Rice  Wheat  Barley  Corn  Peanuts   Sugar  Coconut-oil  Palm-oil  \
# 0       10  0.28   0.11    0.09  0.10     2.12  0.0049         0.28      0.29
# 1       11  0.27   0.11    0.09  0.10     2.11  0.0049         0.34      0.33
# 2       12  0.26   0.11    0.09  0.10     2.00  0.0046         0.32      0.35
# 3        1  0.30   0.11    0.09  0.11     1.85  0.0042         0.34      0.35
# 4        2  0.33   0.11    0.09  0.11     1.79  0.0042         0.33      0.34
# ..     ...   ...    ...     ...   ...      ...     ...          ...       ...
# 355      5  0.51   0.21    0.08  0.14     2.05  0.0053         0.83      0.58
# 356      6  0.52   0.20    0.08  0.15     2.05  0.0060         0.92      0.66
# 357      7  0.48   0.20    0.08  0.15     1.99  0.0060         0.89      0.69
# 358      8  0.50   0.20    0.08  0.15     1.30  0.0064         0.98      0.76
# 359      9  0.51   0.20    0.08  0.17     1.68  0.0062         1.03      0.80
#
#      Sunflower-oil  Chicken    Beef      Pork      Fish   Tea  Coffee  Year
# 0         0.580000   0.0236  0.0571  2.505100  6.350000  1.60    1.24    90
# 1         0.560000   0.0236  0.0558  2.441400  6.460000  1.58    1.22    90
# 2         0.550000   0.0231  0.0562  2.347900  6.500000  1.52    1.24    90
# 3         0.570000   0.0231  0.0571  2.649500  6.340000  1.55    1.16    91
# 4         0.600000   0.0238  0.0602  2.351700  6.410000  1.48    1.14    91
# ..             ...      ...     ...       ...       ...   ...     ...   ...
# 355       0.914201   0.0335  0.1120  1.500345  4.806947  1.97    1.42    20
# 356       0.914201   0.0346  0.1124  1.500345  4.806947  1.86    1.42    20
# 357       0.914201   0.0335  0.1036  1.500345  4.806947  1.78    1.49    20
# 358       0.914201   0.0331  0.1021  1.500345  4.806947  2.00    1.60    20
# 359       0.914201   0.0324  0.1014  1.500345  4.806947  2.05    1.60    20
#
# [360 rows x 17 columns]

# %%
# function for year, use the full year 1990-2020
# instead of only two last numbers

def full_year(row):
    if row['Year'] => 0 ":
        return 1
    elif row['Month'] == "Feb":
        return 2
    elif row['Month'] == "Mar":
        return 3
    elif row['Month'] == "Apr":
        return 4
    elif row['Month'] == "May":
        return 5
    elif row['Month'] == "Jun":
        return 6
    elif row['Month'] == "Jul":
        return 7
    elif row['Month'] == "Aug":
        return 8
    elif row['Month'] == "Sep":
        return 9
    elif row['Month'] == "Oct":
        return 10
    elif row['Month'] == "Nov":
        return 11
    else: 
        return 12
    
df['Year'] = df.apply(full_year, axis=1)
df

# %% [markdown]
# <li>After the cleanups, create a correlation matrix of the data. Create a heatmap on the correlations as well.
# <br /><br />
# Which grocery stands out? (i.e. there seems to be one grocery item
# whose price doesn't follow other groceries at all)
# </li>

# %%
# code here

# %% [markdown]
# <li>Which groceries seem to correlate to each other's prices? What do they have in common?</li>

# %%
# code here

# %% [markdown]
# <b>Bonus task:</b>
# <p>Sometimes data can also reflect history! For example, "Corn" and some
# other foods seem to have a notable peak in its price in one of the years.
# Find this year, and Google if you can find a reason for the price peak (for
# example, search: "us corn expensive XXXX". Can you find any other food
# that has relation to a real world event in a similar in this dataset?</p>
# <p><b>Tip:</b> use pivot table and heatmap! Remember also, the first year in the
# dataset might show as blank white, that means there's no data. You
# should also split the date</p>
# <br />
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_3/food.png" />

# %% [markdown]
# <h2><b>Advanced extra tasks for extra points (varying challenges, some require Googling):</b></h2>

# %% [markdown]
# <ul>
# <li>1. <b>seaborn:</b> Try out Boxenplot and/or Dendrogram in any of the previous
# dataset exercises. Do these plot types provide some interesting info on
# the data? (Google for examples on these plot types)</li>
# <ul>
# <li>You may also consider some other plots, for example:
# <b>displot, catplot, relplot</b></li>
# </ul>
# </ul>

# %%
# code for the advanced extra task

# %% [markdown]
# <ul>
# <li><b>2. Use the "titanic" dataset from the seaborn datasets
# (sns.load_dataset('titanic')).</b> Find out the features of a typical person
# that survived or did not survive the sinking of Titanic.</li>
# </ul>
#
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_3/titanic.png"/>

# %%
# code for the advanced extra task, you can also create a separate notebook for this 
# (might be a better idea, since a new dataset always adds quite much new code)

# %% [markdown]
# <li><b>3. Use the "taxis" dataset from the seaborn datasets
# (sns.load_dataset('taxis')).</b> Find out any correlations or interesting
# behaviors based on any columns in the data (color, payment,
# pickup_borough, dropoff_borough etc.)
# <br /><br />
#
# <b>Notes and ideas to try out:</b><br />
# Consider removing the pickup_zone and dropoff_zone, since there are
# way too many alternatives. Borough is the larger area in question, which
# can be helpful while grouping data (hue!)<br /><br />
# How about pickup and dropoff times, should they be modified? From
# taxi point of view, is the weekday and time of day (morning, day,
# evening, night) more interesting than the actual dates?
# <br /><br />
# These are just ideas, you're free to come up with your own ideas
# regarding the data!</li>
# <br />
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_3/taxis.png"/>

# %%
# code for the advanced extra task, you can also create a separate notebook for this 
# (might be a better idea, since a new dataset always adds quite much new code)

# %% [markdown]
# <ul>
# <li><b>4. Try out any of the previous examples and exercises by using any or many
# of the following additional plotting libraries:<br /><br />
# </li>
# <ul>
# <li><b>Matplotlib (this is the most common in addition to seaborn,
# especially regarding machine learning, recommended to learn)</b><br />
# <a href="https://matplotlib.org/stable/tutorials/index.html#introductory">https://matplotlib.org/stable/tutorials/index.html#introductory</a><br /><br /></li>
# <li><b>Plotly</b><br />
# <a href="https://plotly.com/python/getting-started/">https://plotly.com/python/getting-started/</a><br /><br /></li>
# <li><b>Bokeh</b><br /><a href="https://docs.bokeh.org/en/latest/docs/user_guide.html">https://docs.bokeh.org/en/latest/docs/user_guide.html</a>
# <br /><br /></li>
# </ul>
# </ul>
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_3/charts.png" />

# %%
# code for the advanced extra task, you can also create a separate notebook for this 
# (might be a better idea, since a new dataset always adds quite much new code)

# %% [markdown]
# <ul>
# <li><b>5. Try out any of the datasets below, or find yourself an interesting csvdataset from kaggle.com!  </b><br>
#
# Use all your skills in numpy, pandas and seaborn, and find out features in
# the data. <br ><br />
# <b>Was there something that is surprising in the dataset? What
# interesting correlations did you find?</b>
# <br><br>
# <b>Some interesting datasets, examples (you can find you own too!):</b>
# </li>
# <ul>
# <li><a href="https://www.kaggle.com/anamvillalpando/world-happiness-ranking">https://www.kaggle.com/anamvillalpando/world-happiness-ranking</a></li>
# <li><a href="https://www.kaggle.com/sakshigoyal7/credit-card-customers">https://www.kaggle.com/sakshigoyal7/credit-card-customers</a></li>
# <li><a href="https://www.kaggle.com/lucabasa/dutch-energy">https://www.kaggle.com/lucabasa/dutch-energy</a></li>
# <li><a href="https://www.kaggle.com/yamaerenay/spotify-dataset-19212020-160k-tracks?select=data_w_genres.csv">https://www.kaggle.com/yamaerenay/spotify-dataset-19212020-160k-tracks?select=data_w_genres.csv</a></li>
# <li><a href="https://www.kaggle.com/kboghe/android-apps-metadata?select=Android+apps+csv.csv">https://www.kaggle.com/kboghe/android-apps-metadata?select=Android+apps+csv.csv</a></li>
# <li><a href="https://www.kaggle.com/sudalairajkumar/cryptocurrencypricehistory?select=coin_Bitcoin.csv">https://www.kaggle.com/sudalairajkumar/cryptocurrencypricehistory?select=coin_Bitcoin.csv</a><br /><br /></li>
# </ul>
# <li><b>Note:</b> These datasets can be quite rough to handle at first, feel free to
# ask tips from your instructor if some dataset interests you!</li>
# </ul>
#
# <img src="http://srv.plab.fi/~tuomasv/data_analytics_2023_images/exercise_set_2/es2_5.png" />

# %%
# do any Kaggle.com -related extra tasks in their own Jupyter notebooks for easier coding
