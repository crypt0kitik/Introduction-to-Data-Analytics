# %%
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# data explanations: 
# https://www.kaggle.com/code/akshayraman/eda-coffee-rice-and-beef-prices/data
df = pd.read_csv("ricebeefcoffee.csv")
df = df.drop("Price_beef_kilo", axis = 1)
df = df.drop("Price_coffee_kilo", axis = 1)
df = df.drop("Price_rice_kilo", axis = 1)
df = df.drop("Inflation_rate", axis = 1)

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Price_rice_infl', 'Price_beef_infl',
#        'Price_coffee_infl'],
#       dtype='object')

# %%
df = df.dropna()

# %%
#df=isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/20/hrkxfm3x44z9qt9zqv_zchj00000gn/T/ipykernel_58785/2740897526.py in <module>
# ----> 1 df=isna().sum()
#
# NameError: name 'isna' is not defined

# %%
correlations = df.corr(numeric_only = True)

# %%
# it does not show anything
sns.pairplot(df)

# %%
sns.lmplot(x="Price_rice_infl", y="Price_coffee_infl", data = df)
